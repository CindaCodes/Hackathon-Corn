# %%
import os
import subprocess
subprocess.run(["pip", "install", "python-dotenv", "--quiet"], check=True)

from dotenv import load_dotenv
load_dotenv()

ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
SH_CLIENT_ID = os.getenv("SH_CLIENT_ID")
SH_CLIENT_SECRET = os.getenv("SH_CLIENT_SECRET")

import torch
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
print("Keys loaded:", all([ANTHROPIC_API_KEY, SH_CLIENT_ID, SH_CLIENT_SECRET]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 12
#       8 ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
#       9 SH_CLIENT_ID = os.getenv("SH_CLIENT_ID")
#      10 SH_CLIENT_SECRET = os.getenv("SH_CLIENT_SECRET")
#      11
# ---> 12 import torch
#      13 print("GPU available:", torch.cuda.is_available())
#      14 if torch.cuda.is_available():
#      15     print("GPU:", torch.cuda.get_device_name(0))
#
# ModuleNotFoundError: No module named 'torch'

# %%
#dependencies
# !pip uninstall all
# %pip install segmentation-models-pytorch \
             rasterio \
             geopandas \
             shapely \
             pyproj \
             sentinelhub \
             earthengine-api \
             anthropic \
             fastapi \
             uvicorn \
             python-multipart \
             fiona \
                --quiet
# Out:
# WARNING: Skipping all as it is not installed.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#       CRITICAL:root:A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'fiona' when getting requirements to build wheel
# Note: you may need to restart the kernel to use updated packages.
